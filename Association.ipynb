# %%
import pandas as pd
import numpy as np

# %%
import mlxtend

# %%
dataset=[["Jupe","Baskets","Echarpe","Pantalon","Chapeau"],
        ["Lunettes de soleil","Jupe","Baskets","Pantalon","Chapeau"],
        ["Robes","Sandales","Echarpe","Pantalon","Talons"],
        ["Robes","Coliers","Boucles d'oreilles","Echarpes","Chapeau","Talons","Chapeau"],
        ["Boucles d'oreille","Jupe","Jupe","Echarpe","Chemise","Pantalon"]]

# %%
data=pd.DataFrame(dataset)
data.to_csv("data_csv")
new_data=pd.read_csv("data_csv")
new_data.head()
# Out:
#    Unnamed: 0                   0         1                   2         3  \
# 0           0                Jupe   Baskets             Echarpe  Pantalon
# 1           1  Lunettes de soleil      Jupe             Baskets  Pantalon
# 2           2               Robes  Sandales             Echarpe  Pantalon
# 3           3               Robes   Coliers  Boucles d'oreilles  Echarpes
# 4           4   Boucles d'oreille      Jupe                Jupe   Echarpe
#
#          4         5        6
# 0  Chapeau       NaN      NaN
# 1  Chapeau       NaN      NaN
# 2   Talons       NaN      NaN
# 3  Chapeau    Talons  Chapeau
# 4  Chemise  Pantalon      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
new_data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)
df=pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    Baskets  Boucles d'oreille  Boucles d'oreilles  Chapeau  Chemise  Coliers  \
# 0     True              False               False     True    False    False
# 1     True              False               False     True    False    False
# 2    False              False               False    False    False    False
# 3    False              False                True     True    False     True
# 4    False               True               False    False     True    False
#
#    Echarpe  Echarpes   Jupe  Lunettes de soleil  Pantalon  Robes  Sandales  \
# 0     True     False   True               False      True  False     False
# 1    False     False   True                True      True  False     False
# 2     True     False  False               False      True   True      True
# 3    False      True  False               False     False   True     False
# 4     True     False   True               False      True  False     False
#
#    Talons
# 0   False
# 1   False
# 2    True
# ...

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (3)
# 1      0.6      (6)
# 2      0.6      (8)
# 3      0.8     (10)
# 4      0.6  (10, 6)
# 5      0.6  (8, 10)

# %%
frequent_itemsets=apriori(Df, min_support=0.6, use_colnames=True) 
frequent_itemsets
# Out:
#    support             itemsets
# 0      0.6            (Chapeau)
# 1      0.6            (Echarpe)
# 2      0.6               (Jupe)
# 3      0.8           (Pantalon)
# 4      0.6  (Pantalon, Echarpe)
# 5      0.6     (Pantalon, Jupe)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (Pantalon)   (Echarpe)                 0.8                 0.6      0.6
# 1   (Echarpe)  (Pantalon)                 0.6                 0.8      0.6
# 2  (Pantalon)      (Jupe)                 0.8                 0.6      0.6
# 3      (Jupe)  (Pantalon)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0        0.75  1.25      0.12         1.6
# 1        1.00  1.25      0.12         inf
# 2        0.75  1.25      0.12         1.6
# 3        1.00  1.25      0.12         inf

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0   (Echarpe)  (Pantalon)                 0.6                 0.8      0.6
# 1      (Jupe)  (Pantalon)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf
# 1         1.0  1.25      0.12         inf

# %%
data=pd.read_csv("Market_Basket_Optimisation.csv")

# %%
data.head(15)
# Out:
#                shrimp       almonds        avocado    vegetables mix  \
# 0             burgers     meatballs           eggs               NaN
# 1             chutney           NaN            NaN               NaN
# 2              turkey       avocado            NaN               NaN
# 3       mineral water          milk     energy bar  whole wheat rice
# 4      low fat yogurt           NaN            NaN               NaN
# 5   whole wheat pasta  french fries            NaN               NaN
# 6                soup   light cream        shallot               NaN
# 7   frozen vegetables     spaghetti      green tea               NaN
# 8        french fries           NaN            NaN               NaN
# 9                eggs      pet food            NaN               NaN
# 10            cookies           NaN            NaN               NaN
# 11             turkey       burgers  mineral water              eggs
# 12          spaghetti     champagne        cookies               NaN
# ...

# %%
data.isnull().sum()
# Out:
# shrimp                  0
# almonds              1754
# avocado              3112
# vegetables mix       4156
# green grapes         4972
# whole weat flour     5637
# yams                 6132
# cottage cheese       6520
# energy drink         6847
# tomato juice         7106
# low fat yogurt       7245
# green tea            7347
# honey                7414
# salad                7454
# mineral water        7476
# salmon               7493
# antioxydant juice    7497
# frozen smoothie      7497
# spinach              7498
# olive oil            7500
# dtype: int64

# %%
pip install mlxtend

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)
Df=pd.DataFrame(te_ary,columns=te.columns_)
Df
# Out:
#    Baskets  Boucles d'oreille  Boucles d'oreilles  Chapeau  Chemise  Coliers  \
# 0     True              False               False     True    False    False
# 1     True              False               False     True    False    False
# 2    False              False               False    False    False    False
# 3    False              False                True     True    False     True
# 4    False               True               False    False     True    False
#
#    Echarpe  Echarpes   Jupe  Lunettes de soleil  Pantalon  Robes  Sandales  \
# 0     True     False   True               False      True  False     False
# 1    False     False   True                True      True  False     False
# 2     True     False  False               False      True   True      True
# 3    False      True  False               False     False   True     False
# 4     True     False   True               False      True  False     False
#
#    Talons
# 0   False
# 1   False
# 2    True
# ...

# %%
from mlxtend.frequent_patterns import apriori
apriori(Df, min_support=0.6)
# Out:
#    support itemsets
# 0      0.6      (3)
# 1      0.6      (6)
# 2      0.6      (8)
# 3      0.8     (10)
# 4      0.6  (10, 6)
# 5      0.6  (8, 10)

# %%
frequent_itemsets=apriori(Df, min_support=0.6, use_colnames=True) 
frequent_itemsets
# Out:
#    support             itemsets
# 0      0.6            (Chapeau)
# 1      0.6            (Echarpe)
# 2      0.6               (Jupe)
# 3      0.8           (Pantalon)
# 4      0.6  (Pantalon, Echarpe)
# 5      0.6     (Pantalon, Jupe)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (Pantalon)   (Echarpe)                 0.8                 0.6      0.6
# 1   (Echarpe)  (Pantalon)                 0.6                 0.8      0.6
# 2  (Pantalon)      (Jupe)                 0.8                 0.6      0.6
# 3      (Jupe)  (Pantalon)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0        0.75  1.25      0.12         1.6
# 1        1.00  1.25      0.12         inf
# 2        0.75  1.25      0.12         1.6
# 3        1.00  1.25      0.12         inf

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0   (Echarpe)  (Pantalon)                 0.6                 0.8      0.6
# 1      (Jupe)  (Pantalon)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf
# 1         1.0  1.25      0.12         inf
